# %%
import warnings
# import os
import numpy as np
import pandas as pd
# import time
# import datetime
# import re

from requests import get
from requests.exceptions import RequestException
from contextlib import closing
from bs4 import BeautifulSoup
# from scipy import stats

warnings.filterwarnings('ignore')

# %%
def simple_get(url):
    """
    Attempts to get the content at `url` by making an HTTP GET request.
    If the content-type of response is some kind of HTML/XML, return the
    text content, otherwise return None.
    """
    try:
        with closing(get(url, stream=True)) as resp:
            if is_good_response(resp):
                return resp.content
            else:
                return None

    except RequestException as e:
        log_error('Error during requests to {0} : {1}'.format(url, str(e)))
        return None


def is_good_response(resp):
    """
    Returns True if the response seems to be HTML, False otherwise.
    """
    content_type = resp.headers['Content-Type'].lower()
    return (resp.status_code == 200 
            and content_type is not None 
            and content_type.find('html') > -1)


def log_error(e):
    print(e)

# %%
url = "https://kenpom.com/index.php?y="
raw_html = simple_get(url)
soup = BeautifulSoup(raw_html, 'html5lib')
dta = [s.text for s in soup.select("td")]

dta[:10]
# Out:
# ['1', 'Kansas', 'B12', '26-3', '+30.81', '115.6', '8', '84.8', '1', '67.3']

# %%
lvars = 21
years = range(2000,2021)
url = "https://kenpom.com/index.php?y="
season_dict = {}

for y in years:
    nurl = url + str(y) if y != 2020 else url[:-3]
    raw_html = simple_get(nurl)
    soup = BeautifulSoup(raw_html, 'html5lib')
    dta = [s.text for s in soup.select('td')]
    ldta = len(dta)
    season_dict[y] = pd.DataFrame(np.array(dta).reshape(int((ldta/lvars)),lvars))

# %%
years = list(season_dict.keys())
start = years[-1]
yearsub = years[:-1]

# %%
kenpom = season_dict[start]
kenpom['year'] = start

for y in reversed(yearsub):
    work = season_dict[y]
    work['year'] = y
    kenpom = pd.concat([kenpom,work])
    
kenpom.columns = ['rank','school','conference','w_l','adjem','adjo','adjoR',
                  'adjd','adjdR','adjt','adjtR','luck','luckR','adjems','adjemsR',
                 'oppos','opposR','oppds','oppdsR','adjemn','adjemnR','year']

# %%
meta = [['rank','int'],['adjem','float'],['adjo','float'],['adjoR','int'],
        ['adjd','float'],['adjdR','int'],['adjt','float'],['adjtR','int'],
        ['luck','float'],['luckR','int'],['adjems','float'],['adjemsR','int'],
        ['oppos','float'],['opposR','int'],['oppds','float'],['oppdsR','int'],
        ['adjemn','float'],['adjemnR','int']
       ]
for m in meta: kenpom[m[0]] = kenpom[m[0]].astype(m[1])

kenpom.sort_values(['year','rank'],ascending = 'True',inplace=True)
kenpom.reset_index(inplace=True,drop=True)

# %%
kenpom['wins'] = [int(s.split("-")[0]) for s in kenpom.w_l]
kenpom['losses'] = [int(s.split("-")[1]) for s in kenpom.w_l]
kenpom['wpct'] = kenpom.wins/(kenpom.wins+kenpom.losses)

# %%
kenpom['seed'] = [int(s.split()[-1]) if s.split()[-1].isdigit() else np.NaN for s in kenpom.school]
kenpom['name'] = [s if pd.isna(kenpom.seed[i]) else " ".join(s.split()[:-1]) for (i,s) in enumerate(kenpom.school)]

# %%
colOrder = ['year','rank','school', 'name', 'conference', 'wins',
            'losses','wpct', 'seed', 'w_l','adjem','adjo','adjoR','adjd', 'adjdR','adjt',
            'adjtR','luck','luckR','adjems', 'adjemsR', 'oppos', 'opposR', 'oppds', 'oppdsR', 'adjemn', 'adjemnR',
            ]

kenpom = kenpom[colOrder]

# %%
kenpom.year.min()
# Out:
# 2000

# %%
kenpom.year.max()
# Out:
# 2020

# %%
kenpom.shape
# Out:
# (7216, 27)

# %%
kenpom.head()
# Out:
#    year  rank         school           name conference  wins  losses  \
# 0  2000     1         Kansas         Kansas        B12    26       3
# 1  2000     2        Gonzaga        Gonzaga        WCC    29       2
# 2  2000     3         Baylor         Baylor        B12    25       3
# 3  2000     4  San Diego St.  San Diego St.        MWC    28       1
# 4  2000     5           Duke           Duke        ACC    23       6
#
#        wpct  seed   w_l   ...      luck  luckR  adjems  adjemsR  oppos  \
# 0  0.896552   NaN  26-3   ...     0.031    101   12.74        1  107.3
# 1  0.935484   NaN  29-2   ...     0.045     68    1.71      117  102.9
# 2  0.892857   NaN  25-3   ...     0.004    180    9.37       33  106.1
# 3  0.965517   NaN  28-1   ...     0.010    158    2.62      107  104.9
# 4  0.793103   NaN  23-6   ...    -0.013    222    7.59       46  106.0
#
#    opposR  oppds  oppdsR  adjemn  adjemnR
# 0      20   94.6       1    9.84       11
# 1     130  101.2     104   -1.85      243
# 2      43   96.7      17    1.21      141
# 3      82  102.3     146   -1.36      229
# 4      44   98.5      53    2.72       85
#
# [5 rows x 27 columns]

# %%
kenpom.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7216 entries, 0 to 7215
# Data columns (total 27 columns):
# year          7216 non-null int64
# rank          7216 non-null int64
# school        7216 non-null object
# name          7216 non-null object
# conference    7216 non-null object
# wins          7216 non-null int64
# losses        7216 non-null int64
# wpct          7216 non-null float64
# seed          1652 non-null float64
# w_l           7216 non-null object
# adjem         7216 non-null float64
# adjo          7216 non-null float64
# adjoR         7216 non-null int64
# adjd          7216 non-null float64
# adjdR         7216 non-null int64
# adjt          7216 non-null float64
# adjtR         7216 non-null int64
# luck          7216 non-null float64
# luckR         7216 non-null int64
# adjems        7216 non-null float64
# adjemsR       7216 non-null int64
# oppos         7216 non-null float64
# opposR        7216 non-null int64
# oppds         7216 non-null float64
# oppdsR        7216 non-null int64
# adjemn        7216 non-null float64
# adjemnR       7216 non-null int64
# dtypes: float64(11), int64(12), object(4)
# memory usage: 1.5+ MB

# %%
# sanity check some years

# %%
kenpom.loc[kenpom.year == 2019].head()
# Out:
#       year  rank          school          name conference  wins  losses  \
# 6510  2019     1      Virginia 1      Virginia        ACC    35       3
# 6511  2019     2       Gonzaga 1       Gonzaga        WCC    33       4
# 6512  2019     3  Michigan St. 2  Michigan St.        B10    32       7
# 6513  2019     4          Duke 1          Duke        ACC    32       6
# 6514  2019     5    Texas Tech 3    Texas Tech        B12    31       7
#
#           wpct  seed   w_l   ...      luck  luckR  adjems  adjemsR  oppos  \
# 6510  0.921053   1.0  35-3   ...     0.050     62   11.18       22  109.2
# 6511  0.891892   1.0  33-4   ...    -0.001    180    4.46       75  106.9
# 6512  0.820513   2.0  32-7   ...     0.001    177   13.67        2  110.6
# 6513  0.842105   1.0  32-6   ...     0.018    134   12.85        7  110.7
# 6514  0.815789   3.0  31-7   ...     0.004    171   11.18       21  109.8
#
#       opposR  oppds  oppdsR  adjemn  adjemnR
# 6510      34   98.1      14   -3.24      255
# 6511      69  102.5      87    1.87      105
# 6512       7   96.9       1    3.24       82
# 6513       4   97.8      11    5.08       40
# 6514      19   98.7      22   -5.39      307
#
# [5 rows x 27 columns]

# %%
kenpom.loc[kenpom.year == 2010].head()
# Out:
#       year  rank           school           name conference  wins  losses  \
# 3371  2010     1           Duke 1           Duke        ACC    35       5
# 3372  2010     2         Kansas 1         Kansas        B12    33       3
# 3373  2010     3       Syracuse 1       Syracuse         BE    30       5
# 3374  2010     4       Kentucky 1       Kentucky        SEC    35       3
# 3375  2010     5  West Virginia 2  West Virginia         BE    31       7
#
#           wpct  seed   w_l   ...      luck  luckR  adjems  adjemsR  oppos  \
# 3371  0.875000   1.0  35-5   ...     0.009    145   11.53        4  107.9
# 3372  0.916667   1.0  33-3   ...     0.038     83    9.53       16  108.2
# 3373  0.857143   1.0  30-5   ...    -0.008    191    8.62       36  108.5
# 3374  0.921053   1.0  35-3   ...     0.060     43    7.06       55  106.5
# 3375  0.815789   2.0  31-7   ...     0.057     45   12.58        1  110.0
#
#       opposR  oppds  oppdsR  adjemn  adjemnR
# 3371      19   96.4       1    2.50       94
# 3372      16   98.7      32    1.13      125
# 3373      10   99.8      67   -2.96      246
# 3374      50   99.5      57   -1.28      194
# 3375       1   97.5       7    5.45       50
#
# [5 rows x 27 columns]

# %%
kenpom.loc[kenpom.year != 2020].to_csv('kenpom.csv',index=False)
